# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv(r'C:\Users\Dell\Downloads\CAR DETAILS.csv')
df
# Out:
#                                      name  year  selling_price  km_driven
# 0                           Maruti 800 AC  2007          60000      70000  \
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# 0     Petrol  Individual       Manual   First Owner
# 1     Petrol  Individual       Manual   First Owner
# 2     Diesel  Individual       Manual   First Owner
# 3     Petrol  Individual       Manual   First Owner
# 4     Diesel  Individual       Manual  Second Owner
# ...      ...         ...          ...           ...
# 4335  Diesel  Individual       Manual  Second Owner
# 4336  Diesel  Individual       Manual  Second Owner
# 4337  Petrol  Individual       Manual  Second Owner
# 4338  Diesel  Individual       Manual   First Owner
# 4339  Petrol  Individual       Manual   First Owner
#
# [4340 rows x 8 columns]

# %%
df['name'].value_counts()
# Out:
# name
# Maruti Swift Dzire VDI                     69
# Maruti Alto 800 LXI                        59
# Maruti Alto LXi                            47
# Maruti Alto LX                             35
# Hyundai EON Era Plus                       35
#                                            ..
# Hyundai Verna Transform CRDi VGT SX ABS     1
# Maruti S-Presso VXI Plus                    1
# Toyota Etios Liva 1.2 VX                    1
# Toyota Yaris G                              1
# Hyundai i20 Magna 1.4 CRDi                  1
# Name: count, Length: 1491, dtype: int64

# %%
df.shape
# Out:
# (4340, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   year           4340 non-null   int64
#  2   selling_price  4340 non-null   int64
#  3   km_driven      4340 non-null   int64
#  4   fuel           4340 non-null   object
#  5   seller_type    4340 non-null   object
#  6   transmission   4340 non-null   object
#  7   owner          4340 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 271.4+ KB

# %%
df.isnull().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# dtype: int64

# %%
df.duplicated().value_counts()
# Out:
# False    3577
# True      763
# Name: count, dtype: int64

# %%
df.drop_duplicates(subset=None,inplace=True)

# %%
df.shape
# Out:
# (3577, 8)

# %%
df.describe()
# Out:
#               year  selling_price      km_driven
# count  3577.000000   3.577000e+03    3577.000000
# mean   2012.962538   4.739125e+05   69250.545709
# std       4.251759   5.093018e+05   47579.940016
# min    1992.000000   2.000000e+04       1.000000
# 25%    2010.000000   2.000000e+05   36000.000000
# 50%    2013.000000   3.500000e+05   60000.000000
# 75%    2016.000000   6.000000e+05   90000.000000
# max    2020.000000   8.900000e+06  806599.000000

# %%
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel
# 0             Maruti 800 AC  2007          60000      70000  Petrol  \
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
import datetime

# %%
date_time=datetime.datetime.now()

# %%
print(date_time)
# Out:
# 2023-10-31 17:45:16.845008

# %%
df['age']=date_time.year-df['year']

# %%
df
# Out:
#                                      name  year  selling_price  km_driven
# 0                           Maruti 800 AC  2007          60000      70000  \
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner  age
# 0     Petrol  Individual       Manual   First Owner   16
# 1     Petrol  Individual       Manual   First Owner   16
# 2     Diesel  Individual       Manual   First Owner   11
# 3     Petrol  Individual       Manual   First Owner    6
# 4     Diesel  Individual       Manual  Second Owner    9
# ...      ...         ...          ...           ...  ...
# 4335  Diesel  Individual       Manual  Second Owner    9
# 4336  Diesel  Individual       Manual  Second Owner    9
# 4337  Petrol  Individual       Manual  Second Owner   14
# 4338  Diesel  Individual       Manual   First Owner    7
# 4339  Petrol  Individual       Manual   First Owner    7
#
# [3577 rows x 9 columns]

# %%
df1=df.copy()

# %%
df1.drop('year',axis=1,inplace=True)

# %%
df1.head()
# Out:
#                        name  selling_price  km_driven    fuel seller_type
# 0             Maruti 800 AC          60000      70000  Petrol  Individual  \
# 1  Maruti Wagon R LXI Minor         135000      50000  Petrol  Individual
# 2      Hyundai Verna 1.6 SX         600000     100000  Diesel  Individual
# 3    Datsun RediGO T Option         250000      46000  Petrol  Individual
# 4     Honda Amaze VX i-DTEC         450000     141000  Diesel  Individual
#
#   transmission         owner  age
# 0       Manual   First Owner   16
# 1       Manual   First Owner   16
# 2       Manual   First Owner   11
# 3       Manual   First Owner    6
# 4       Manual  Second Owner    9

# %% [markdown]
# #### removing the outliers

# %%
sns.boxplot(df1['selling_price'])
# Out:
# <Axes: >

# %%
sorted(df1['selling_price'],reverse=True)
# Out:
# [8900000,
#  8150000,
#  5500000,
#  4950000,
#  4800000,
#  4800000,
#  4700000,
#  4500000,
#  4500000,
#  4400000,
#  4200000,
#  4000000,
#  4000000,
#  4000000,
#  3899000,
#  3800000,
#  3500000,
#  3500000,
#  3256000,
#  3200000,
#  3200000,
#  3200000,
#  3100000,
#  3100000,
#  3050000,
#  2900000,
#  2800000,
#  2800000,
#  2800000,
#  2800000,
#  2750000,
#  2750000,
#  2700000,
#  2700000,
#  2700000,
#  2675000,
#  2675000,
#  2650000,
#  2600000,
#  2600000,
#  2595000,
#  2575000,
#  2550000,
#  2500000,
#  2500000,
#  2500000,
#  2500000,
#  2490000,
#  2400000,
#  2349000,
#  2300000,
#  2300000,
#  2200000,
#  2150000,
#  2100000,
#  2050000,
#  2000000,
#  2000000,
#  2000000,
#  2000000,
#  1975000,
#  1964999,
#  1950000,
#  1900000,
#  1900000,
#  1900000,
#  1900000,
#  1860000,
#  1850000,
#  1850000,
#  1825000,
#  1800000,
#  1800000,
#  1800000,
#  1800000,
#  1800000,
#  1800000,
#  1800000,
#  1770000,
#  1750000,
#  1750000,
#  1750000,
#  1735000,
#  1725000,
#  1700000,
#  1700000,
#  1700000,
#  1700000,
#  1700000,
#  1700000,
#  1680000,
#  1650000,
#  1650000,
#  1600000,
#  1600000,
#  1600000,
#  1580000,
#  1575000,
#  1550000,
#  1549000,
#  1500000,
#  1500000,
#  1500000,
#  1500000,
#  1500000,
#  1500000,
#  1500000,
#  1500000,
#  1490000,
#  1490000,
#  1490000,
#  1485000,
#  1475000,
#  1470000,
#  1451000,
#  1450000,
#  1425000,
#  1400000,
#  1400000,
#  1400000,
#  1400000,
#  1400000,
#  1400000,
#  1400000,
#  1400000,
#  1400000,
#  1380000,
#  1375000,
#  1375000,
#  1350000,
#  1350000,
#  1350000,
#  1350000,
#  1350000,
#  1350000,
#  1350000,
#  1334000,
#  1331000,
#  1330000,
#  1300000,
#  1300000,
#  1300000,
#  1300000,
#  1300000,
#  1300000,
#  1300000,
#  1300000,
#  1300000,
#  1295000,
#  1295000,
#  1290000,
#  1280000,
#  1260000,
#  1250000,
#  1250000,
#  1250000,
#  1250000,
#  1250000,
#  1250000,
#  1250000,
#  1250000,
#  1250000,
#  1250000,
#  1250000,
#  1249000,
#  1249000,
#  1240000,
#  1230000,
#  1225000,
#  1225000,
#  1200000,
#  1200000,
#  1200000,
#  1200000,
#  1200000,
#  1200000,
#  1200000,
#  1200000,
#  1200000,
#  1200000,
#  1200000,
#  1200000,
#  1200000,
#  1200000,
#  1200000,
#  1199000,
#  1195000,
#  1190000,
#  1189000,
#  1165000,
#  1151000,
#  1150000,
#  1150000,
#  1150000,
#  1150000,
#  1150000,
#  1150000,
#  1150000,
#  1150000,
#  1150000,
#  1150000,
#  1150000,
#  1140000,
#  1125000,
#  1119000,
#  1100000,
#  1100000,
#  1100000,
#  1100000,
#  1100000,
#  1100000,
#  1100000,
#  1100000,
#  1100000,
#  1100000,
#  1100000,
#  1100000,
#  1100000,
#  1100000,
#  1100000,
#  1090000,
#  1085000,
#  1075000,
#  1068000,
#  1050000,
#  1050000,
#  1050000,
#  1050000,
#  1050000,
#  1050000,
#  1050000,
#  1050000,
#  1050000,
#  1044999,
#  1044999,
#  1040000,
#  1035000,
#  1030000,
#  1030000,
#  1025000,
#  1025000,
#  1025000,
#  1025000,
#  1025000,
#  1015000,
#  1010000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  1000000,
#  999000,
#  990000,
#  980000,
#  980000,
#  975000,
#  975000,
#  969999,
#  969999,
#  950000,
#  950000,
#  950000,
#  950000,
#  950000,
#  950000,
#  950000,
#  950000,
#  950000,
#  950000,
#  950000,
#  950000,
#  950000,
#  950000,
#  950000,
#  950000,
#  950000,
#  950000,
#  950000,
#  950000,
#  940000,
#  940000,
#  940000,
#  940000,
#  940000,
#  936999,
#  930000,
#  930000,
#  930000,
#  927999,
#  925000,
#  925000,
#  925000,
#  925000,
#  925000,
#  925000,
#  925000,
#  925000,
#  919999,
#  919999,
#  910000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  900000,
#  894999,
#  894999,
#  890000,
#  890000,
#  890000,
#  890000,
#  890000,
#  890000,
#  890000,
#  880000,
#  875000,
#  875000,
#  875000,
#  875000,
#  869999,
#  869999,
#  865000,
#  861999,
#  860000,
#  860000,
#  860000,
#  852000,
#  851000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  850000,
#  844999,
#  844999,
#  841000,
#  840000,
#  840000,
#  840000,
#  836000,
#  836000,
#  835000,
#  830000,
#  830000,
#  830000,
#  830000,
#  828999,
#  825000,
#  825000,
#  825000,
#  825000,
#  825000,
#  825000,
#  825000,
#  825000,
#  821000,
#  819999,
#  819999,
#  819999,
#  819999,
#  815000,
#  811999,
#  810000,
#  802000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  800000,
#  799000,
#  795000,
#  795000,
#  790000,
#  790000,
#  790000,
#  790000,
#  790000,
#  790000,
#  790000,
#  785000,
#  785000,
#  784000,
#  784000,
#  782000,
#  782000,
#  780000,
#  780000,
#  780000,
#  780000,
#  780000,
#  780000,
#  780000,
#  780000,
#  775000,
#  775000,
#  775000,
#  774000,
#  770000,
#  770000,
#  765000,
#  763000,
#  760000,
#  760000,
#  760000,
#  760000,
#  760000,
#  755000,
#  751000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  750000,
#  749000,
#  746000,
#  744000,
#  740000,
#  740000,
#  740000,
#  738000,
#  735000,
#  730000,
#  730000,
#  730000,
#  725000,
#  725000,
#  725000,
#  725000,
#  725000,
#  725000,
#  725000,
#  725000,
#  725000,
#  725000,
#  725000,
#  725000,
#  725000,
#  724000,
#  721000,
#  720000,
#  720000,
#  720000,
#  720000,
#  720000,
#  716000,
#  715000,
#  715000,
#  715000,
#  715000,
#  711000,
#  711000,
#  710000,
#  710000,
#  710000,
#  707000,
#  701000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  700000,
#  699000,
#  699000,
#  699000,
#  696000,
#  695000,
#  690000,
#  690000,
#  690000,
#  690000,
#  690000,
#  690000,
#  690000,
#  690000,
#  690000,
#  685000,
#  685000,
#  685000,
#  680000,
#  680000,
#  680000,
#  680000,
#  680000,
#  680000,
#  680000,
#  675000,
#  675000,
#  675000,
#  675000,
#  675000,
#  675000,
#  675000,
#  675000,
#  675000,
#  675000,
#  675000,
#  675000,
#  670000,
#  670000,
#  670000,
#  670000,
#  665000,
#  665000,
#  665000,
#  665000,
#  665000,
#  665000,
#  660000,
#  660000,
#  660000,
#  660000,
#  660000,
#  660000,
#  655000,
#  655000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  650000,
#  641000,
#  640000,
#  640000,
#  640000,
#  640000,
#  640000,
#  640000,
#  640000,
#  640000,
#  640000,
#  639000,
#  635000,
#  635000,
#  635000,
#  630000,
#  630000,
#  630000,
#  630000,
#  630000,
#  630000,
#  630000,
#  630000,
#  628000,
#  625000,
#  625000,
#  625000,
#  625000,
#  625000,
#  625000,
#  625000,
#  625000,
#  625000,
#  625000,
#  624000,
#  620000,
#  620000,
#  620000,
#  620000,
#  620000,
#  620000,
#  620000,
#  620000,
#  620000,
#  619000,
#  619000,
#  615000,
#  615000,
#  615000,
#  615000,
#  614000,
#  612000,
#  611000,
#  610000,
#  610000,
#  610000,
#  610000,
#  610000,
#  610000,
#  610000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  600000,
#  599000,
#  599000,
#  599000,
#  596000,
#  595000,
#  595000,
#  595000,
#  595000,
#  590000,
#  590000,
#  590000,
#  590000,
#  587000,
#  585000,
#  585000,
#  585000,
#  585000,
#  585000,
#  585000,
#  580000,
#  580000,
#  580000,
#  580000,
#  580000,
#  580000,
#  580000,
#  580000,
#  580000,
#  580000,
#  580000,
#  580000,
#  575000,
#  575000,
#  575000,
#  575000,
#  575000,
#  575000,
#  575000,
#  575000,
#  575000,
#  575000,
#  575000,
#  575000,
#  570000,
#  570000,
#  570000,
#  570000,
#  570000,
#  570000,
#  565000,
#  565000,
#  565000,
#  565000,
#  560000,
#  560000,
#  556000,
#  555000,
#  555000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  550000,
#  ...]

# %%
df1=df1[~(df1['selling_price']>=8150000) & (df1['selling_price']<=8900000)]

# %%
df1.shape
# Out:
# (3575, 8)

# %% [markdown]
# #### exploratory data analysis

# %%
df1.columns
# Out:
# Index(['name', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'age'],
#       dtype='object')

# %%
fuel=df1['fuel']
seller_type=df1['seller_type']
transmission=df1['transmission']
selling_price=df1['selling_price']
owner=df1['owner']

# %%
from matplotlib import style

# %%
style.use('ggplot')
fig=plt.figure(figsize=(15,5))
fig.suptitle('visualizing categorical data columns')
plt.subplot(1,4,1)
plt.bar(fuel,selling_price, color='royalblue')
plt.xlabel('fuel type')
plt.ylabel('selling price')
plt.subplot(1,4,2)
plt.bar(seller_type,selling_price,color='orange')
plt.xlabel('seller type')
plt.subplot(1,4,3)
plt.bar(transmission,selling_price,color='green')
plt.xlabel('transmission type')
plt.subplot(1,4,4)
plt.bar(owner,selling_price,color='purple')
plt.xticks(rotation=90)
plt.xlabel('types of owner')
plt.show()

# %% [markdown]
# #### encoding the categorical columns

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb=LabelEncoder()

# %%
df1['name']=lb.fit_transform(df1['name'])
df1['fuel']=lb.fit_transform(df1['fuel'])
df1['seller_type']=lb.fit_transform(df1['seller_type'])
df1['transmission']=lb.fit_transform(df1['transmission'])
df1['owner']=lb.fit_transform(df1['owner'])

# %%
df1.head()
# Out:
#    name  selling_price  km_driven  fuel  seller_type  transmission  owner  age
# 0   774          60000      70000     4            1             1      0   16
# 1  1040         135000      50000     4            1             1      0   16
# 2   504         600000     100000     1            1             1      0   11
# 3   117         250000      46000     4            1             1      0    6
# 4   278         450000     141000     1            1             1      2    9

# %%
df1.drop('name',axis=1,inplace=False)
# Out:
#       selling_price  km_driven  fuel  seller_type  transmission  owner  age
# 0             60000      70000     4            1             1      0   16
# 1            135000      50000     4            1             1      0   16
# 2            600000     100000     1            1             1      0   11
# 3            250000      46000     4            1             1      0    6
# 4            450000     141000     1            1             1      2    9
# ...             ...        ...   ...          ...           ...    ...  ...
# 4335         409999      80000     1            1             1      2    9
# 4336         409999      80000     1            1             1      2    9
# 4337         110000      83000     4            1             1      2   14
# 4338         865000      90000     1            1             1      0    7
# 4339         225000      40000     4            1             1      0    7
#
# [3575 rows x 7 columns]

# %% [markdown]
# #### splitting train and test data

# %%
x=df1.drop(['selling_price'],axis=1)
y=df1['selling_price']
print(type(x))
print(type(y))
print(x.shape)
print(y.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>
# (3575, 7)
# (3575,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30,random_state=42)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (2502, 7)
# (1073, 7)
# (2502,)
# (1073,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
def reg_eval_metrics (y,ypred):
    mae=mean_absolute_error(y,ypred)
    mse=mean_squared_error(y,ypred)
    rmse=np.sqrt(mean_squared_error(y,ypred))
    r2=r2_score(y,ypred)
    print('MAE', mae)
    print('MSE',mse)
    print('RMSE',rmse)
    print('R2_SCORE',r2)
    
    
def train_test_scr(model):
    print('training score',model.score(x_train,y_train))
    print('testing score',model.score(x_test,y_test))

# %% [markdown]
# #### linear regressor model

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
ypred_lr=lr.predict(x_test)
train_test_scr(lr)
# Out:
# training score 0.4648172463643314
# testing score 0.45582298258296716

# %%
reg_eval_metrics(y_test,ypred_lr)
# Out:
# MAE 216905.30038896884
# MSE 152631521801.78458
# RMSE 390680.8439145495
# R2_SCORE 0.45582298258296716

# %%
m=lr.coef_
c=lr.intercept_
print(m)
print(c)
# Out:
# [-2.54013651e+01 -6.09809165e-01 -8.21752880e+04 -1.62873991e+04
#  -6.84874841e+05 -1.62813840e+04 -3.54477335e+04]
# 1736385.5256775457

# %% [markdown]
# #### randomforest regressor model

# %%
rf= RandomForestRegressor(max_depth=15,min_samples_split=2,min_samples_leaf=5,random_state=42)
rf.fit(x_train,y_train)
ypred_rf=rf.predict(x_test)
train_test_scr(rf)
# Out:
# training score 0.7947377851513461
# testing score 0.6291665499590922

# %%
reg_eval_metrics(y_test,ypred_rf)
# Out:
# MAE 148675.0575352555
# MSE 104011878493.89355
# RMSE 322508.7262290643
# R2_SCORE 0.6291665499590922

# %% [markdown]
# #### gradient boosting regressor model

# %%
gbr=GradientBoostingRegressor(max_depth=10,max_features=100,n_estimators=1500,learning_rate=0.05,subsample=0.8,min_samples_split=500,min_samples_leaf=30,random_state=42)
gbr.fit(x_train,y_train)
ypred_gbr=gbr.predict(x_test)
train_test_scr(gbr)
# Out:
# training score 0.8878312054820723
# testing score 0.7956954940446559

# %%
reg_eval_metrics(y_test,ypred_gbr)
# Out:
# MAE 118389.79573409479
# MSE 57303610143.14658
# RMSE 239381.72474762268
# R2_SCORE 0.7956954940446559

# %% [markdown]
# #### Ada boost regressor model

# %%
adr=AdaBoostRegressor()
adr.fit(x_train,y_train)
ypred_adr=adr.predict(x_test)
train_test_scr(adr)
# Out:
# training score 0.4253090102102206
# testing score 0.4573855016805023

# %%
reg_eval_metrics(y_test,ypred_adr)
# Out:
# MAE 258121.17397956946
# MSE 152193264286.1821
# RMSE 390119.5512739423
# R2_SCORE 0.4573855016805023

# %% [markdown]
# #### choosing the best model

# %%
def reg_eval_metrics(y, ypred):
    r2 = r2_score(y, ypred)
    return r2

r2_score_result = reg_eval_metrics(y_test, ypred_lr)
print("R2_SCORE of Linear regressor", r2_score_result)

r2_score_result = reg_eval_metrics(y_test, ypred_rf)
print("R2_SCORE of Randomforest", r2_score_result)

r2_score_result = reg_eval_metrics(y_test, ypred_gbr)
print("R2_SCORE of Gradientboost", r2_score_result)

r2_score_result = reg_eval_metrics(y_test, ypred_adr)
print("R2_SCORE of Adaboost", r2_score_result)
# Out:
# R2_SCORE of Linear regressor 0.45582298258296716
# R2_SCORE of Randomforest 0.6291665499590922
# R2_SCORE of Gradientboost 0.7956954940446559
# R2_SCORE of Adaboost 0.4573855016805023

# %% [markdown]
# #### Gradient boost regressor has the comparitively high r2_score and less in mean squared error, mean absolute error and root of mean squred error.

# %%
df1['selling_price_pred']=gbr.predict(x)
df1.head()
# Out:
#    name  selling_price  km_driven  fuel  seller_type  transmission  owner
# 0   774          60000      70000     4            1             1      0  \
# 1  1040         135000      50000     4            1             1      0
# 2   504         600000     100000     1            1             1      0
# 3   117         250000      46000     4            1             1      0
# 4   278         450000     141000     1            1             1      2
#
#    age  selling_price_pred
# 0   16        83290.255551
# 1   16       126202.185838
# 2   11       474405.411250
# 3    6       239598.693800
# 4    9       484897.610962

# %%
df1.head(1)
# Out:
#    name  selling_price  km_driven  fuel  seller_type  transmission  owner
# 0   774          60000      70000     4            1             1      0  \
#
#    age  selling_price_pred
# 0   16        83290.255551

# %%
plt.figure(figsize=(15,5))
sns.regplot(data=df1,x='selling_price',y='selling_price_pred',color='blue')
plt.xlabel('selling price',color='blue')
plt.ylabel('predicted selling price',color='red')
plt.show()

# %% [markdown]
# #### saving the predicted values of a car selling price  dataset into csv file

# %%
df1.to_csv('selling_price_prediction.csv')

# %%
import pickle

# %%
model=GradientBoostingRegressor(max_depth=10,max_features=100,n_estimators=300,learning_rate=0.05,subsample=0.8,min_samples_split=500,min_samples_leaf=30,random_state=42)
model.fit(x_train,y_train)
# Out:
# GradientBoostingRegressor(learning_rate=0.05, max_depth=10, max_features=100,
#                           min_samples_leaf=30, min_samples_split=500,
#                           n_estimators=300, random_state=42, subsample=0.8)

# %% [markdown]
# #### saving the model using pickle

# %%
with open('gb_regressor_model.pkl', 'wb') as file:
    pickle.dump(model, file)

# %% [markdown]
# #### load the model form the file

# %%
with open('gb_regressor_model.pkl', 'rb') as file:
    loaded_model = pickle.load(file)

# %%
print(loaded_model)
# Out:
# GradientBoostingRegressor(learning_rate=0.05, max_depth=10, max_features=100,
#                           min_samples_leaf=30, min_samples_split=500,
#                           n_estimators=300, random_state=42, subsample=0.8)

# %% [markdown]
# #### checking that file is loaded or not

# %%
if loaded_model is not None:
    print("File loaded successfully.")
else:
    print("File did not load properly.")
# Out:
# File loaded successfully.

# %% [markdown]
# #### randomly picking 20 datas from the dataset

# %%
import random

# %%
random_df1=df.sample(n=20,random_state=42)
random_df1
# Out:
#                                           name  year  selling_price
# 1045        Maruti Eeco 7 Seater Standard BSIV  2018         270000  \
# 3194                     Maruti Swift VXi BSIV  2017         525000
# 1530     Toyota Innova 2.5 G (Diesel) 8 Seater  2016         990000
# 553   Mercedes-Benz C-Class Progressive C 220d  2018        3800000
# 1612                      Honda Civic 1.8 S MT  2007         229999
# 2652                       Mahindra Xylo E4 8S  2010         325000
# 152                       Hyundai Getz 1.3 GLS  2008         210000
# 3985                Fiat Punto EVO 1.3 Dynamic  2016         500000
# 1059                  Honda Jazz 1.5 VX i DTEC  2018         790000
# 3788                     Honda Amaze E i-Vtech  2015         360000
# 1252                  Chevrolet Beat Diesel LT  2012         250000
# 3631                        Hyundai Verna CRDi  2009         160000
# 964                     Maruti Swift Dzire VDI  2018         500000
# 4069                  Maruti Wagon R VXI Minor  2012         229999
# 1581                 Hyundai i20 Asta 1.4 CRDi  2013         360000
# 2555                  Honda Jazz 1.2 VX i VTEC  2016         612000
# 2353                           Toyota Etios VD  2012         350000
# 1700             Mahindra Bolero 2011-2019 SLX  2019         800000
# 2214                 Ford Figo Diesel Titanium  2010         160000
# 753                   Maruti Wagon R LXI BS IV  2013         330000
#
#       km_driven    fuel seller_type transmission         owner  age
# 1045      20000  Petrol  Individual       Manual   First Owner    5
# 3194      39000  Petrol      Dealer       Manual   First Owner    6
# 1530     146000  Diesel      Dealer       Manual   First Owner    7
# 553       10000  Diesel      Dealer    Automatic   First Owner    5
# 1612      70000  Petrol  Individual       Manual  Second Owner   16
# 2652     120000  Diesel  Individual       Manual   Third Owner   13
# 152       53772  Petrol  Individual       Manual   First Owner   15
# 3985      35000  Diesel  Individual       Manual   First Owner    7
# 1059      19571  Diesel      Dealer       Manual   First Owner    5
# 3788      80000  Petrol  Individual       Manual  Second Owner    8
# 1252     110000  Diesel  Individual       Manual   First Owner   11
# 3631      90000  Diesel  Individual       Manual   First Owner   14
# 964       50000  Diesel  Individual       Manual   First Owner    5
# 4069      25000  Petrol  Individual       Manual   First Owner   11
# 1581      80000  Diesel  Individual       Manual  Second Owner   10
# 2555     105429  Petrol      Dealer       Manual   First Owner    7
# 2353     140000  Diesel  Individual       Manual   Third Owner   11
# 1700      24000  Diesel  Individual       Manual   First Owner    4
# 2214     102307  Diesel      Dealer       Manual   First Owner   13
# 753       55425  Petrol      Dealer       Manual   First Owner   10

# %%
random_df1.shape
# Out:
# (20, 9)

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
random_df1['name']=lb.fit_transform(random_df1['name'])
random_df1['fuel']=lb.fit_transform(random_df1['fuel'])
random_df1['seller_type']=lb.fit_transform(random_df1['seller_type'])
random_df1['transmission']=lb.fit_transform(random_df1['transmission'])
random_df1['owner']=lb.fit_transform(random_df1['owner'])

# %%
a=random_df1.drop(['selling_price'],axis=1)
b=random_df1['selling_price']
print(type(a))
print(type(b))
print(a.shape)
print(b.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>
# (20, 8)
# (20,)

# %%
from sklearn.model_selection import train_test_split
a_train,a_test,b_train,b_test = train_test_split(a,b,test_size=0.30,random_state=42)
print(a_train.shape)
print(a_test.shape)
print(b_train.shape)
print(b_test.shape)
# Out:
# (14, 8)
# (6, 8)
# (14,)
# (6,)

# %%
def reg_eval_metrics (b,bpred):
    mae=mean_absolute_error(b,bpred)
    mse=mean_squared_error(b,bpred)
    rmse=np.sqrt(mean_squared_error(b,bpred))
    r2=r2_score(b,bpred)
    print('MAE', mae)
    print('MSE',mse)
    print('RMSE',rmse)
    print('R2_SCORE',r2)
    
    
def train_test_scr(model):
    print('training score',model.score(a_train,b_train))
    print('testing score',model.score(a_test,b_test))

# %%
testing_gbr=GradientBoostingRegressor(max_depth=5,n_estimators=5,random_state=5,learning_rate=0.1)
testing_gbr.fit(a_train,b_train)
ypred_testing_gbr=testing_gbr.predict(a_test)
train_test_scr(testing_gbr)
# Out:
# training score 0.6511074886779415
# testing score 0.13363348950006582

# %%
reg_eval_metrics(b_test,ypred_testing_gbr)
# Out:
# MAE 167577.69917394168
# MSE 36605910327.53444
# RMSE 191326.7109619941
# R2_SCORE 0.13363348950006582
